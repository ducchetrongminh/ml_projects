# %%
# Run this code when reset session
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
import subprocess
# !python '/content/gdrive/My Drive/projects/ml_projects/colab_setup.py'

# %%
import sys
sys.path.append('/content/gdrive/My Drive/projects/ml_projects')
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from pandas import read_csv as _read_csv
from sklearn.model_selection import train_test_split

# %%
# Dataset source: https://www.kaggle.com/CooperUnion/cardataset/data
# I uploaded this dataset to my github for convenience
data_url = 'https://raw.githubusercontent.com/alexjdata/ml_projects/master/ml_projects/linear_regression/car_dataset.csv'
data_df = _read_csv(data_url)

# %%
data_df.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
train_df, test_df = train_test_split(data_df, test_size=0.2)

# %%
car_prediction_model = UnivariateLinearRegression(
    training_set = train_df, 
    input_feature = 'Engine HP', 
    output_feature = 'MSRP'
)

car_prediction_model.set_learning_rate(0.00001)
car_prediction_model.set_test_set(test_df)
car_prediction_model.train()
# Out:
# Dropped 51 null rows of training set
# Dropped 18 null rows of test set
# Start training.
# Init theta_0: 0, theta_1: 0, cost: 2419697760.86577
# Iterate: 1, new cost: 1158377168.6696334
# Iterate: 2, new cost: 1071304351.8604599
# Iterate: 3, new cost: 1065292964.0008208
# Iterate: 4, new cost: 1064877460.9304937
# Iterate: 5, new cost: 1064848256.5857813
# Iterate: 6, new cost: 1064845719.4652482
# Iterate: 7, new cost: 1064845023.2553723
# Finish training. theta_0: 0.12354482982156972, theta_1: 191.69653431239786

# %%
car_prediction_model.test()
# Out:
# Cost of test set: 1869505047.047491
# 1869505047.047491

# %%
car_prediction_model.predict(600)
# Out:
# Predicted value: 115018.04413226854
# 115018.04413226854

# %%
train_df.head()
# Out:
#           Make                    Model  Year  ... city mpg  Popularity    MSRP
# 2164     Dodge                  Caliber  2012  ...       24        1851   17380
# 2852   Bentley  Continental Flying Spur  2011  ...       11         520  181200
# 3428     Dodge                   Dakota  2008  ...       14        1851   30780
# 10402  Hyundai                  Tiburon  2008  ...       17        1439   20170
# 4606      Ford                    F-250  1997  ...       12        5657    2529
#
# [5 rows x 16 columns]

# %%
output_feature = 'MSRP'

# %%
input_features = train_df.columns.to_list()
input_features.remove(output_feature)

# %%
input_features
# Out:
# ['Make',
#  'Model',
#  'Year',
#  'Engine Fuel Type',
#  'Engine HP',
#  'Engine Cylinders',
#  'Transmission Type',
#  'Driven_Wheels',
#  'Number of Doors',
#  'Market Category',
#  'Vehicle Size',
#  'Vehicle Style',
#  'highway MPG',
#  'city mpg',
#  'Popularity']

# %%
for input_feature in input_features:
    if train_df[input_feature].dtype not in [np.int64, np.float64]:
        continue
        
    plt.plot(train_df[input_feature], train_df[output_feature], 'r.')
    plt.xlabel(input_feature)
    plt.ylabel(output_feature)
    plt.suptitle(input_feature)
    plt.show()

# %%
train_df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
train_df['Year'].dtype == np.int64
# Out:
# True

# %%
def plot_by_feature(df_, output_feature):
    input_features = df_.columns.to_list()
    input_features.remove(output_feature)

    for input_feature in input_features:
        if df_[input_feature].dtype not in [np.int64, np.float64]:
            continue
            
        plt.plot(df_[input_feature], df_[output_feature], 'r.')
        plt.xlabel(input_feature)
        plt.ylabel(output_feature)
        plt.suptitle(input_feature)
        plt.show()
        print('\n\n\n')

# %%
print('\n\n\n')
