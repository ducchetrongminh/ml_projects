# %%
test_data = [
    [['a','b'], ['c'], ['f','g'], ['g'], ['e']],
    [['a','d'], ['c'], ['b'], ['a','b','e','f']],
    [['a'],['b'], ['f','g'], ['e']],
    [['b'], ['f','g']]
]

# %%
test_data[0][0][1]
# Out:
# 'b'
